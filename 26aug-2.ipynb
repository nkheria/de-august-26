# %%
# %sql
select * from retail_catalog_02.sales_analytics.bronze_sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from retail_catalog_02.sales_analytics.silver_sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SHOW TABLE EXTENDED LIKE 'retail_catalog_02.sales_analytics.silver_sales';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th><th>information</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SHOW TABLES IN retail_catalog_02.sales_analytics;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>sales_analytics</td><td>bronze_products</td><td>false</td></tr><tr><td>sales_analytics</td><td>bronze_sales</td><td>false</td></tr><tr><td>sales_analytics</td><td>gold_daily_revenue</td><td>false</td></tr><tr><td>sales_analytics</td><td>gold_product_performance</td><td>false</td></tr><tr><td>sales_analytics</td><td>silver_products</td><td>false</td></tr><tr><td>sales_analytics</td><td>silver_sales</td><td>false</td></tr><tr><td></td><td>_sqldf</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
USE CATALOG retail_catalog_02

# %%
# %sql
SHOW TABLE EXTENDED IN retail_catalog_02.sales_analytics LIKE 'silver_sales';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th><th>information</th></tr></thead><tbody><tr><td>sales_analytics</td><td>silver_sales</td><td>false</td><td>Catalog: retail_catalog_02
# Database: sales_analytics
# Table: silver_sales
# Created Time: Tue Aug 26 08:54:53 UTC 2025
# Last Access: UNKNOWN
# Created By: Spark
# Type: MATERIALIZED_VIEW
# Comment: Cleaned sales data (Silver)
# Table Properties: [pipelines.pipelineId=52e8c6e2-d597-49a1-ba86-0acd35c29ca5]
# Schema: root
#  |-- sale_id: integer (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- region: string (nullable = true)
# ...

# %%
# %sql
CREATE TABLE retail_catalog_02.sales_analytics.silver_sales_table
AS SELECT * FROM retail_catalog_02.sales_analytics.silver_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
DESCRIBE HISTORY retail_catalog_02.sales_analytics.silver_sales_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE HISTORY retail_catalog_02.sales_analytics.bronze_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT *
FROM retail_catalog_02.sales_analytics.bronze_sales VERSION AS OF 6;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE HISTORY retail_catalog_02.sales_analytics.silver_sales;
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-4524406251009302>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', 'DESCRIBE HISTORY retail_catalog_02.sales_analytics.silver_sales;\n')
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /databricks/python_shell/lib/dbruntime/sql_magic/sql_magic.py:130, in SqlMagic.sql(self, line, cell)
# ...
